# %%
#!pip install seaborn

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/content/EV_Dataset.csv')

# %%
df.head()
# Out:
#      Year Month_Name      Date           State         Vehicle_Class  \
# 0  2014.0        jan  1/1/2014  Andhra Pradesh       ADAPTED VEHICLE
# 1  2014.0        jan  1/1/2014  Andhra Pradesh  AGRICULTURAL TRACTOR
# 2  2014.0        jan  1/1/2014  Andhra Pradesh             AMBULANCE
# 3  2014.0        jan  1/1/2014  Andhra Pradesh   ARTICULATED VEHICLE
# 4  2014.0        jan  1/1/2014  Andhra Pradesh                   BUS
#
#   Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# 0           Others       Others                0.0
# 1           Others       Others                0.0
# 2           Others       Others                0.0
# 3           Others       Others                0.0
# 4              Bus          Bus                0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96845 entries, 0 to 96844
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               96845 non-null  float64
#  1   Month_Name         96845 non-null  object
#  2   Date               96845 non-null  object
#  3   State              96845 non-null  object
#  4   Vehicle_Class      96845 non-null  object
#  5   Vehicle_Category   96845 non-null  object
#  6   Vehicle_Type       96845 non-null  object
#  7   EV_Sales_Quantity  96845 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 5.9+ MB

# %% [markdown]
# # Categorical Data

# %% [markdown]
# ## a) Countplot

# %%
sns.countplot(df['Vehicle_Category'])
# Out:
# <Axes: xlabel='count', ylabel='Vehicle_Category'>

# %%
df.describe()
# Out:
#                Year  EV_Sales_Quantity
# count  96845.000000       96845.000000
# mean    2018.622768          37.108896
# std        2.895581         431.566675
# min     2014.000000           0.000000
# 25%     2016.000000           0.000000
# 50%     2019.000000           0.000000
# 75%     2021.000000           0.000000
# max     2024.000000       20584.000000

# %%
sns.countplot(df['Vehicle_Type'])
# Out:
# <Axes: xlabel='count', ylabel='Vehicle_Type'>

# %%
sns.countplot(df['State'])
# Out:
# <Axes: xlabel='count', ylabel='State'>

# %%
df['State'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sns.displot(df['Month_Name'])

# %%
# import pandas as pd
# from time import strptime

# # Assuming your DataFrame is named 'df' and the month column is named 'Month_Name'
# df['Month_Number'] = [strptime(str(x), '%b').tm_mon for x in df['Month_Name']]

# %%
df.tail()
# Out:
#          Year Month_Name       Date                     State  \
# 96840  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96841  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96842  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96843  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96844  2023.0        dec  12/1/2023  Andaman & Nicobar Island
#
#                            Vehicle_Class Vehicle_Category Vehicle_Type  \
# 96840                          MOTOR CAR       4-Wheelers  4W_Personal
# 96841  MOTOR CYCLE/SCOOTER-USED FOR HIRE       2-Wheelers    2W_Shared
# 96842                           OMNI BUS              Bus          Bus
# 96843              THREE WHEELER (GOODS)       3-Wheelers     3W_Goods
# 96844          THREE WHEELER (PASSENGER)       3-Wheelers    3W_Shared
#
#        EV_Sales_Quantity
# 96840                1.0
# 96841                5.0
# 96842                0.0
# 96843                0.0
# 96844                0.0

# %%
#sns.distplot(df['Month_Number'])

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Month_Name'],bins=30)
# Out:
# (array([8853.,    0., 8072.,    0.,    0., 8435.,    0.,    0., 7917.,
#            0., 7622.,    0.,    0., 7852.,    0.,    0., 7983.,    0.,
#            0., 7896.,    0., 8044.,    0.,    0., 8017.,    0.,    0.,
#         8078.,    0., 8076.]),
#  array([ 0.        ,  0.36666667,  0.73333333,  1.1       ,  1.46666667,
#          1.83333333,  2.2       ,  2.56666667,  2.93333333,  3.3       ,
#          3.66666667,  4.03333333,  4.4       ,  4.76666667,  5.13333333,
#          5.5       ,  5.86666667,  6.23333333,  6.6       ,  6.96666667,
#          7.33333333,  7.7       ,  8.06666667,  8.43333333,  8.8       ,
#          9.16666667,  9.53333333,  9.9       , 10.26666667, 10.63333333,
#         11.        ]),
#  <BarContainer object of 30 artists>)

# %%
sns.boxplot(df['EV_Sales_Quantity'])
# Out:
# <Axes: ylabel='EV_Sales_Quantity'>

# %%
sns.boxplot(df['Year'])
# Out:
# <Axes: ylabel='Year'>

# %%
df['EV_Sales_Quantity'].skew()
# Out:
# 24.58528454008108

# %%
df.sample(10)
# Out:
#          Year Month_Name       Date                     State  \
# 66697  2016.0        sep   9/1/2016                 Rajasthan
# 60555  2018.0        aug   8/1/2018             Uttar Pradesh
# 45384  2019.0        jun   6/1/2019            Madhya Pradesh
# 90452  2016.0        dec  12/1/2016                       Goa
# 44698  2018.0        jun   6/1/2018                Tamil Nadu
# 14622  2021.0        feb   2/1/2021              Chhattisgarh
# 50966  2016.0        jul   7/1/2016               West Bengal
# 55225  2022.0        jul   7/1/2022                       Goa
# 96843  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 60700  2019.0        aug   8/1/2019  Andaman & Nicobar Island
#
#                    Vehicle_Class Vehicle_Category Vehicle_Type  \
# 66697      CRANE MOUNTED VEHICLE           Others       Others
# 60555              BREAKDOWN VAN           Others       Others
# 45384                     DUMPER           Others       Others
# ...

# %%
df
# Out:
#          Year Month_Name       Date                     State  \
# 0      2014.0        jan   1/1/2014            Andhra Pradesh
# 1      2014.0        jan   1/1/2014            Andhra Pradesh
# 2      2014.0        jan   1/1/2014            Andhra Pradesh
# 3      2014.0        jan   1/1/2014            Andhra Pradesh
# 4      2014.0        jan   1/1/2014            Andhra Pradesh
# ...       ...        ...        ...                       ...
# 96840  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96841  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96842  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96843  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96844  2023.0        dec  12/1/2023  Andaman & Nicobar Island
#
#                            Vehicle_Class Vehicle_Category Vehicle_Type  \
# 0                        ADAPTED VEHICLE           Others       Others
# 1                   AGRICULTURAL TRACTOR           Others       Others
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1mgJ7Zso9B8ySs61jrLma9GtFzB2vfIcKlJifS6Fgmxk#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1mgJ7Zso9B8ySs61jrLma9GtFzB2vfIcKlJifS6Fgmxk#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# @title Vehicle_Category

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Vehicle_Category').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# prompt: Using dataframe df: suggest univaraiate analysis for both numerical and catagorical column data

# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame

# Univariate analysis for numerical columns
numerical_cols = ['Year', 'EV_Sales_Quantity']

for col in numerical_cols:
    print(f"Analysis for {col}:")

    # Summary statistics
    print(df[col].describe())

    # Distribution plot
    plt.figure(figsize=(8, 6))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

    # Box plot to check for outliers
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot of {col}')
    plt.show()
    print("-" * 30)


# Univariate analysis for categorical columns
categorical_cols = ['Month_Name', 'State', 'Vehicle_Class', 'Vehicle_Category', 'Vehicle_Type']

for col in categorical_cols:
    print(f"Analysis for {col}:")

    # Value counts and percentage
    print(df[col].value_counts(normalize=True) * 100)

    # Bar plot
    plt.figure(figsize=(10, 6))
    df[col].value_counts().plot(kind='bar')
    plt.title(f'Frequency of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right') # Rotate x-axis labels if needed
    plt.tight_layout() # Adjust layout to prevent labels from overlapping
    plt.show()
    print("-" * 30)
# Out:
# Analysis for Year:
# count    96845.000000
# mean      2018.622768
# std          2.895581
# min       2014.000000
# 25%       2016.000000
# 50%       2019.000000
# 75%       2021.000000
# max       2024.000000
# Name: Year, dtype: float64
# ------------------------------
# Analysis for EV_Sales_Quantity:
# count    96845.000000
# mean        37.108896
# std        431.566675
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      20584.000000
# Name: EV_Sales_Quantity, dtype: float64
# ------------------------------
# Analysis for Month_Name:
# Month_Name
# jan    9.141412
# mar    8.709794
# nov    8.341164
# dec    8.339099
# feb    8.334968
# sep    8.306056
# oct    8.278176
# jul    8.243069
# apr    8.174919
# aug    8.153235
# jun    8.107801
# may    7.870308
# Name: proportion, dtype: float64
# ------------------------------
# Analysis for State:
# State
# Maharashtra                 5.072022
# ...

# %%
df['Vehicle_Category'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['Year'],bins=25)
# Out:
# (array([ 9022.,     0.,  9052.,     0.,     0.,  9348.,     0.,  9799.,
#             0.,     0., 10225.,     0., 10315.,     0.,     0.,  8675.,
#             0.,  9249.,     0.,     0., 10021.,     0., 10279.,     0.,
#           860.]),
#  array([2014. , 2014.4, 2014.8, 2015.2, 2015.6, 2016. , 2016.4, 2016.8,
#         2017.2, 2017.6, 2018. , 2018.4, 2018.8, 2019.2, 2019.6, 2020. ,
#         2020.4, 2020.8, 2021.2, 2021.6, 2022. , 2022.4, 2022.8, 2023.2,
#         2023.6, 2024. ]),
#  <BarContainer object of 25 artists>)

# %%
plt.hist(df['Month_Name'],bins=30)
# Out:
# (array([8853.,    0., 8072.,    0.,    0., 8435.,    0.,    0., 7917.,
#            0., 7622.,    0.,    0., 7852.,    0.,    0., 7983.,    0.,
#            0., 7896.,    0., 8044.,    0.,    0., 8017.,    0.,    0.,
#         8078.,    0., 8076.]),
#  array([ 0.        ,  0.36666667,  0.73333333,  1.1       ,  1.46666667,
#          1.83333333,  2.2       ,  2.56666667,  2.93333333,  3.3       ,
#          3.66666667,  4.03333333,  4.4       ,  4.76666667,  5.13333333,
#          5.5       ,  5.86666667,  6.23333333,  6.6       ,  6.96666667,
#          7.33333333,  7.7       ,  8.06666667,  8.43333333,  8.8       ,
#          9.16666667,  9.53333333,  9.9       , 10.26666667, 10.63333333,
#         11.        ]),
#  <BarContainer object of 30 artists>)

# %%
sns.displot(df['Year'])

# %%
sns.displot(df['Year'],kde=True,stat="density")

# %%
sns.displot(df['Month_Name'])

# %%
sns.displot(df['Month_Name'],kde=True,stat="density")

# %%
sns.boxplot(df['Year'])
# Out:
# <Axes: ylabel='Year'>

# %%
sns.boxplot(df['EV_Sales_Quantity'])
# Out:
# <Axes: ylabel='EV_Sales_Quantity'>

# %%
# prompt: code to see the skewness plot for EV_Sales_Quantity

plt.figure(figsize=(8, 6))
sns.histplot(df['EV_Sales_Quantity'], kde=True)
plt.title('Distribution of EV_Sales_Quantity')
plt.show()
