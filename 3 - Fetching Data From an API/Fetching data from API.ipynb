# %%
import pandas as pd
import requests

# %% [markdown]
# ![TMDB API.png](attachment:f72f0526-9ac7-4698-b1b7-21f33317a8ce.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Use your own API Read Access Token in the code below

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiMTdlOTA0MmM3MWMyY2M5YzViZTc4ODQ2N2U2NzMzZCIsIm5iZiI6MTczNDYyMDI1NC42MTIsInN1YiI6IjY3NjQzNDVlOGQxY2ZkYzUyMjRhNjExOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.5OSWLrLVB-YsAewuax3JF3dB_DysnNFNN4lsQif_kJE"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 157.014, 'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.708, 'vote_count': 27324}, {'adult': False, 'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg', 'genre_ids': [18, 80], 'id': 238, 'original_language': 'en', 'original_title': 'The Godfather', 'overview': 'Spanning
# ...

# %% [markdown]
# Page 1 (First page): JSON response from API

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Page 492 (Last Page): JSON response from API

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Page 493: No data or results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Online JSON viewer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Another URL to fetch data from UPI
#
#
# response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b17e9042c71c2cc9c5be788467e6733d&language=en-US&page=1')

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 157.014,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.708,
#    'vote_count': 27324},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response.json()['page']
# Out:
# 1

# %%
response.json()['results'][0]
# Out:
# {'adult': False,
#  'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#  'genre_ids': [18, 80],
#  'id': 278,
#  'original_language': 'en',
#  'original_title': 'The Shawshank Redemption',
#  'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#  'popularity': 157.014,
#  'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#  'release_date': '1994-09-23',
#  'title': 'The Shawshank Redemption',
#  'video': False,
#  'vote_average': 8.708,
#  'vote_count': 27324}

# %%
print(response.json())
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 157.014, 'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.708, 'vote_count': 27324}, {'adult': False, 'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg', 'genre_ids': [18, 80], 'id': 238, 'original_language': 'en', 'original_title': 'The Godfather', 'overview': 'Spanning
# ...

# %%
print(response.json()['results'][0])
# Out:
# {'adult': False, 'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 157.014, 'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.708, 'vote_count': 27324}

# %%
df1 = pd.DataFrame(response.json()['results'])

# %%
df1
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]     278
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]     238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /bxgTSUenZDHNFerQ1whRKplrMKF.jpg              [18]     389
# 5   False  /m4TUa2ciEWSlk37rOsjiSIvZDXE.jpg   [16, 10751, 14]     129
# 6   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 7   False  /oOv2oUXcAaNXakRqUPxYq5lJURz.jpg  [18, 28, 80, 53]     155
# 8   False  /b3mdmjYTEL70j7nuXATUAD9qgu4.jpg      [16, 14, 12]  823219
# 9   False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg      [14, 18, 80]     497
# 10  False  /x6skktR5OS99lAX4JhmjCQYq490.jpg      [35, 53, 18]  496243
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# ...

# %%
df2 = df1[['id','original_title','title','popularity','release_date','vote_average','vote_count']]

# %%
df2
# Out:
#         id                                 original_title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                       千と千尋の神隠し
# 6    19404                   दिलवाले दुल्हनिया ले जायेंगे
# 7      155                                The Dark Knight
# 8   823219                                        Straume
# 9      497                                 The Green Mile
# 10  496243                                            기생충
# 11     680                                   Pulp Fiction
# 12  372058                                          君の名は。
# 13     122  The Lord of the Rings: The Return of the King
# 14      13                                   Forrest Gump
# ...

# %%
df3 = pd.DataFrame(response.json()['results'])[['id','title']]

# %%
df3
# Out:
#         id                                          title
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6    19404                    Dilwale Dulhania Le Jayenge
# 7      155                                The Dark Knight
# 8   823219                                           Flow
# 9      497                                 The Green Mile
# 10  496243                                       Parasite
# 11     680                                   Pulp Fiction
# 12  372058                                     Your Name.
# 13     122  The Lord of the Rings: The Return of the King
# 14      13                                   Forrest Gump
# ...

# %%
df=pd.DataFrame()

# %% [markdown]
# df
#
# It is a blank dataframe

# %% [markdown]
# Using 2nd API url link
# The For loop code to get data from all 492 pages and storing it in a DataFrame:
#
# for i in range(1,493):
#
#     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b17e9042c71c2cc9c5be788467e6733d&language=en-US&page={}'.format(i))
#
#     temp_df = pd.DataFrame(response.json()['results'])[['id','original_title','title','popularity','release_date','vote_average','vote_count']]
#
#     df = pd.concat([df, temp_df], ignore_index=True)

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# Total 492 pages with 9822 results

# %% [markdown]
# #### To get data from all 492 pages and storing them in a DataFrame 'df'

# %%
for i in range(1,493):

    url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i)

    headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiMTdlOTA0MmM3MWMyY2M5YzViZTc4ODQ2N2U2NzMzZCIsIm5iZiI6MTczNDYyMDI1NC42MTIsInN1YiI6IjY3NjQzNDVlOGQxY2ZkYzUyMjRhNjExOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.5OSWLrLVB-YsAewuax3JF3dB_DysnNFNN4lsQif_kJE"
    }

    response = requests.get(url, headers=headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id','original_title','title','popularity','release_date','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %% [markdown]
# It took 5 minutes 6 seconds to execute above code. So we may have to wait here depending on the network resource we are using during this exercise.

# %%
df
# Out:
#          id              original_title                       title  \
# 0       278    The Shawshank Redemption    The Shawshank Redemption
# 1       238               The Godfather               The Godfather
# 2       240       The Godfather Part II       The Godfather Part II
# 3       424            Schindler's List            Schindler's List
# 4       389                12 Angry Men                12 Angry Men
# ...     ...                         ...                         ...
# 9817  12142           Alone in the Dark           Alone in the Dark
# 9818  13805              Disaster Movie              Disaster Movie
# 9819  11059           House of the Dead           House of the Dead
# 9820  14164        Dragonball Evolution        Dragonball Evolution
# 9821  40016  Birdemic: Shock and Terror  Birdemic: Shock and Terror
#
#       popularity release_date  vote_average  vote_count
# 0        157.014   1994-09-23         8.708       27324
# ...

# %%
df.shape
# Out:
# (9822, 7)

# %% [markdown]
# # Loading the DataFrame to a CSV file

# %%
df.to_csv('movies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9822 entries, 0 to 9821
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              9822 non-null   int64
#  1   original_title  9822 non-null   object
#  2   title           9822 non-null   object
#  3   popularity      9822 non-null   float64
#  4   release_date    9822 non-null   object
#  5   vote_average    9822 non-null   float64
#  6   vote_count      9822 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 537.3+ KB

# %%
df.head()
# Out:
#     id            original_title                     title  popularity  \
# 0  278  The Shawshank Redemption  The Shawshank Redemption     157.014
# 1  238             The Godfather             The Godfather     155.451
# 2  240     The Godfather Part II     The Godfather Part II      87.158
# 3  424          Schindler's List          Schindler's List      89.846
# 4  389              12 Angry Men              12 Angry Men      60.134
#
#   release_date  vote_average  vote_count
# 0   1994-09-23         8.708       27324
# 1   1972-03-14         8.700       20737
# 2   1974-12-20         8.600       12509
# 3   1993-12-15         8.567       15926
# 4   1957-04-10         8.500        8722

# %%
df.tail()
# Out:
#          id              original_title                       title  \
# 9817  12142           Alone in the Dark           Alone in the Dark
# 9818  13805              Disaster Movie              Disaster Movie
# 9819  11059           House of the Dead           House of the Dead
# 9820  14164        Dragonball Evolution        Dragonball Evolution
# 9821  40016  Birdemic: Shock and Terror  Birdemic: Shock and Terror
#
#       popularity release_date  vote_average  vote_count
# 9817      13.491   2005-01-28         3.244         607
# 9818      21.945   2008-08-29         3.165        1028
# 9819      13.893   2003-04-11         3.100         387
# 9820      22.907   2009-03-12         2.900        2043
# 9821      14.437   2010-02-27         2.166         338

# %%
df.describe()
# Out:
#                  id   popularity  vote_average    vote_count
# count  9.822000e+03  9822.000000   9822.000000   9822.000000
# mean   1.979640e+05    29.708185      6.630993   1980.385665
# std    2.626589e+05    91.711550      0.783154   3143.535969
# min    2.000000e+00     0.018000      2.166000    300.000000
# 25%    1.016150e+04    15.489250      6.100000    466.000000
# 50%    3.777000e+04    20.548500      6.664000    843.000000
# 75%    3.597690e+05    29.833500      7.200000   1965.750000
# max    1.241982e+06  6247.102000      8.708000  36682.000000

# %% [markdown]
# This is how we can fetch the data from an API and convert it to Pandas DataFrame for any further data analysis.
